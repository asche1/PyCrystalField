# %% [markdown]
# # Import crystal structure of $\rm Yb_2Ti_2O_7$ from cif file and calculate the crystal field Hamiltonian

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

import PyCrystalField as cef

# %%
########### Import CIF file

YTOLig, Yb = cef.importCIF('yto.cif','Yb1')
# Out:
# Importing atoms
#    99 atoms added
# .cif import complete.
# Central ion: Yb3+ at [0.5, 0.5, 0.5]
#    Found 3 fold axis about [1. 1. 1.]
#    Found mirror plane: [-0.70710678  0.          0.70710678]
#    Identified 8 O2- ligands.
#
#   Axes for point charge model (in ABC space):
#         X axis = [-0.40824829  0.81649658 -0.40824829]
#         Y axis = [-0.70710678  0.          0.70710678]
#         Z axis = [0.57735027 0.57735027 0.57735027]
#
#    Creating a point charge model...
# B_2 0  =  0.53552196
# B_2 1  =  -0.0
# B_2 2  =  -0.0
# B_4 0  =  -0.04430884
# B_4 1  =  0.0
# B_4 2  =  -0.0
# B_4 3  =  0.33472584
# B_4 4  =  -0.0
# B_6 0  =  0.00032957
# B_6 1  =  -0.0
# B_6 2  =  -0.0
# B_6 3  =  0.00302494
# B_6 4  =  -0.0
# B_6 5  =  -0.0
# B_6 6  =  0.00313667

# %%
########### print eigenvectors

Yb.diagonalize()
Yb.printEigenvectors()
# Out:
#  Eigenvalues 	 Eigenvectors
# 		---------------------------------------------------------------
# 0.00000 	|  [ 0.374  0.     0.     0.921  0.     0.    -0.105  0.   ]  |
# 0.00000 	|  [ 0.    -0.105  0.     0.    -0.921  0.     0.     0.374]  |
# 38.61543 	|  [ 0.     0.001  0.     0.    -0.376  0.     0.    -0.926]  |
# 38.61543 	|  [ 0.926  0.     0.    -0.376  0.     0.    -0.001  0.   ]  |
# 47.10950 	|  [ 0.     0.    -0.121  0.     0.     0.993  0.     0.   ]  |
# 47.10950 	|  [0.    0.    0.993 0.    0.    0.121 0.    0.   ]  |
# 75.14028 	|  [ 0.04  -0.     0.     0.097  0.     0.     0.994  0.   ]  |
# 75.14028 	|  [ 0.     0.994  0.     0.    -0.097  0.     0.     0.04 ]  |
# 		---------------------------------------------------------------

# %%
########### plot neutron spectrum

hw = np.linspace(0,100,200)
intens = Yb.neutronSpectrum(hw, Temp=20, Ei=120, ResFunc= lambda x: 4, gamma = 1)

plt.figure()
plt.plot(hw, intens)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Plot Susceptibility of RE kagome compounds
#
# Allen Scheie
# January, 2018

# %%
# Import libraries
# %matplotlib notebook
# Import libraries
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import Normalize
from matplotlib.ticker import FuncFormatter
import sys
sys.path.append('/home/allen/Documents/Python/Modules')
import CEF_calculations as cef
import time
import plotformat as pf

# %%
import pickle

with open('NdMg_CEF_fitResults.pickle', 'rb') as f:
    NdCoefFit1, NdFitB, FitGamma, FitPrefactors = pickle.load(f)
    #NdCoefFit1, FitCoefficients, FitGamma, FitPrefactors = pickle.load(f)
# with open('NdMg_CEF_fitResults_FitSus.pickle', 'rb') as f:
#     NdCoefFit1, FitCoefficients, FitOcc, FitGamma, FitPrefactors = pickle.load(f)

NdCoefFit1.diagonalize()
NdCoefFit1.printEigenvectors()
NdCoefFit1.gsExpectation()



# ### Import Susceptibility data
# Import data
NMdatafile = './Data/'+\
                'Nd3Sb3Mg2O14 MT 1.8 to 300 5000 oe 53.8 mg.dc.dat'
#ImportData
NMDataA = np.genfromtxt(NMdatafile, delimiter=',', skip_header=31)
NMTemp = NMDataA[:,3]
NMMag = NMDataA[:,4]

#Normalize the data
NMmass = 0.0538 #mass in g of sample
NMMolarmass = 3*144.242 + 3*121.76 + 2*24.305 + 14*15.9994  #molar mass of sample (g/mol)
NMfield = 5000

NMNormMag = NMMag / NMmass * NMMolarmass / 3 / NMfield
NMChiminus1 = 1/NMNormMag  # in emu/Oe/mol
NMChiminus1 *= 1/(1.078283e20*10000/6.0221409e23)  # in mu_B/T/ion



# Import data from other compounds

##*********************************
## NdZn
##**********************************


with open('NdZn_CEF_fitResults.pickle', 'rb') as f:
    NdZnCoefFit1, NZFitB, NZFitGamma, NZFitPrefactors = pickle.load(f)
    #NdCoefFit1, FitCoefficients, FitGamma, FitPrefactors = pickle.load(f)

NdZnCoefFit1.diagonalize()
NdZnCoefFit1.printEigenvectors()
NdZnCoefFit1.gsExpectation()



# ### Import Susceptibility data
# Import data
NZdatafile = './Data/'+\
                'Nd3Sb3Zn2O14 MT 5000 oe.dc.dat'
#ImportData
NZDataA = np.genfromtxt(NZdatafile, delimiter=',', skip_header=31)
NZTemp = NZDataA[:,3]
NZMag = NZDataA[:,4]

#Normalize the data
NZmass = 0.0777 #mass in g of sample
NZMolarmass = 3*144.242 + 3*121.76 + 2*65.38 + 14*15.9994  #molar mass of sample (g/mol)
NZfield = 5000

NZNormMag = NZMag / NZmass * NZMolarmass / 3 / NZfield
NZChiminus1 = 1/NZNormMag  # in emu/Oe/mol
NZChiminus1 *= 1/(1.078283e20*10000/6.0221409e23)  # in mu_B/T/ion







##*********************************
## PrMg
##**********************************
with open('PrMg_CEF_fitResults.pickle', 'rb') as f:
    PrMgCoefFit1, PMFitB, PMFitGamma, PMFitPrefactors = pickle.load(f)
    #NdCoefFit1, FitCoefficients, FitGamma, FitPrefactors = pickle.load(f)

PrMgCoefFit1.diagonalize()
PrMgCoefFit1.printEigenvectors()
PrMgCoefFit1.gsExpectation()



# ### Import Susceptibility data
# Import data
PMdatafile = './Data/'+\
                'Pr3Sb3Mg2O14.dc.dat'
#ImportData
PMDataA = np.genfromtxt(PMdatafile, delimiter=',', skip_header=31)
PMTemp = PMDataA[:,3]
PMMag = PMDataA[:,4]

#Normalize the data
PMmass = 0.0583 #mass in g of sample
PMMolarmass = 3*140.90766 + 3*121.76 + 2*24.305 + 14*15.9994  #molar mass of sample (g/mol)
PMfield = 1000

PMNormMag = PMMag / PMmass * PMMolarmass / 3 / PMfield
PMChiminus1 = 1/PMNormMag  # in emu/Oe/mol
PMChiminus1 *= 1/(1.078283e20*10000/6.0221409e23)  # in mu_B/T/ion
# Out:
#  Eigenvalues 	 Eigenvectors
# 		-----------------------------------------------------------------------------
# 0.00000 	|  [ 0.883 -0.029 -0.035  0.209 -0.12   0.033  0.396  0.036  0.007  0.011]  |
# 0.00000 	|  [ 0.011 -0.007  0.036 -0.396  0.033  0.12   0.209  0.035 -0.029 -0.883]  |
# 23.17920 	|  [-0.431  0.081 -0.373  0.417 -0.08   0.089  0.667  0.185 -0.039 -0.032]  |
# 23.17920 	|  [ 0.032 -0.039 -0.185  0.667 -0.089 -0.08  -0.417 -0.373 -0.081 -0.431]  |
# 36.36020 	|  [-0.118 -0.086  0.412  0.064 -0.808  0.373 -0.021  0.019  0.114  0.   ]  |
# 36.36020 	|  [ 0.    -0.114  0.019  0.021  0.373  0.808  0.064 -0.412 -0.086  0.118]  |
# 43.69117 	|  [ 0.134  0.134 -0.578 -0.106 -0.147  0.391 -0.406  0.521 -0.093 -0.   ]  |
# 43.69117 	|  [-0.     0.093  0.521  0.406  0.391  0.147 -0.106  0.578  0.134 -0.134]  |
# 110.70845 	|  [ 0.035  0.955  0.053 -0.023 -0.035  0.058  0.009 -0.216  0.178  0.   ]  |
# ...

# %%
NMcalcsuscep = NdCoefFit1.susceptibility('Nd3+', NMTemp,  0.5, 0.001)
NZcalcsuscep = NdZnCoefFit1.susceptibility('Nd3+', NZTemp,  0.5, 0.001)
PMcalcsuscep = PrMgCoefFit1.susceptibility('Pr3+', PMTemp,  0.5, 0.001)



cpal = plt.cm.tab10(np.arange(10))
NMcol = cpal[3]
NZcol = cpal[4]
PMcol = cpal[2]
fitcolor=[0.1,0.1,0.3]


f, ax = plt.subplots(3,1, figsize=(6,7), sharex=True)

subplotlabels='abcdefg'
Temps = [NMTemp, NZTemp, PMTemp]
Chiminus1s = [NMChiminus1, NZChiminus1, PMChiminus1]
Calcsusceps = [NMcalcsuscep, NZcalcsuscep, PMcalcsuscep]
colors = [NMcol, NZcol, PMcol]
CompoundNames = ['$\\rm{Nd_3Sb_3Mg_2O_{14}}$', '$\\rm{Nd_3Sb_3Zn_2O_{14}}$', '$\\rm{Pr_3Sb_3Mg_2O_{14}}$']
yaxeslabels = ['$\chi^{-1}$ ($\mu_B$/T/Nd)$^{-1}$', '$\chi^{-1}$ ($\mu_B$/T/Nd)$^{-1}$', 
               '$\chi^{-1}$ ($\mu_B$/T/Pr)$^{-1}$']
Fields = ['0.5 T', '0.5 T', '0.1 T']

for i,axx in enumerate(ax):
    axx.plot(Temps[i],Chiminus1s[i], 's', markersize=4,mew=0.5,mec=colors[i]*np.array([0.5,0.5,0.5,1]), 
             c=colors[i], label='data')
    axx.plot(Temps[i],-1/(Calcsusceps[i]), label='calculation', c=fitcolor)
    axx.set_ylabel(yaxeslabels[i])
    axx.text(0.5,0.96,CompoundNames[i],
            horizontalalignment='center',verticalalignment='top', transform=axx.transAxes)
    
    axx.text(0.02,0.94, '('+subplotlabels[i]+')', fontsize=16,
        horizontalalignment='left',verticalalignment='top', transform=axx.transAxes)
    axx.text(0.98,0.6, Fields[i],
        horizontalalignment='right',verticalalignment='bottom', transform=axx.transAxes)
    axx.legend(loc=4, handlelength=1.5)

ax[2].set_xlabel('$T$ (K)')
ax[2].set_xticks([0,100,200,300])
    
plt.tight_layout()
plt.subplots_adjust(hspace=0.01)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# # Re-plot susceptibility, taking into account the 10% impurities

# %%
fitres = [ 0.87137689,  0.09125306, -3.18776238]  #see PrMg-PlotResults notebook
#fitres = [ 0.90000888,  (2.34190946/2.11333)**2*(1-0.90000888), -4.75472351]

cpal = plt.cm.tab10(np.arange(10))
NMcol = cpal[3]
NZcol = cpal[4]
PMcol = cpal[2]
fitcolor=[0.1,0.1,0.3]
colors = [NMcol, NZcol, PMcol]

plt.rc('font',**{'size':14})
f, ax = plt.subplots(3,1, figsize=(6,7), sharex=True)

for i,axx in enumerate(ax):
    impurityCalcSus = fitres[1]/(Temps[i]-fitres[2])-fitres[0]*Calcsusceps[i]
    axx.plot(Temps[i],Chiminus1s[i], 's', markersize=5,mew=1,mec=colors[i], 
             c='w', label='data')
    
    axx.plot(Temps[i],-1/(Calcsusceps[i]), label='calc. (CEF)', c=[.65,.65,.65], ls='--', lw=1.6)
    axx.plot(Temps[i],1/(impurityCalcSus), label='calc. w. impurity', c='k', lw=2.0)
    axx.set_ylabel(yaxeslabels[i])
    axx.text(0.5,0.96,CompoundNames[i],
            horizontalalignment='center',verticalalignment='top', transform=axx.transAxes)
    
    axx.text(0.02,0.94, '('+subplotlabels[i]+')', fontsize=16,
        horizontalalignment='left',verticalalignment='top', transform=axx.transAxes)
    axx.text(0.98,0.6, Fields[i],
        horizontalalignment='right',verticalalignment='bottom', transform=axx.transAxes)
    axx.legend(loc=4, handlelength=1.3, fontsize=13)

ax[2].set_xlabel('$T$ (K)', fontsize=15)
ax[2].set_xticks([0,100,200,300])
    
plt.tight_layout()
plt.subplots_adjust(hspace=0.01)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# # Try fitting $\chi' = \frac{\chi}{1-\lambda \chi}$

# %%
def chifitfun(x, lam):
    return x/(1-lam*x)

f, ax = plt.subplots(3,1, figsize=(6,7), sharex=True)

subplotlabels='abcdefg'
Temps = [NMTemp, NZTemp, PMTemp]
Chiminus1s = [NMChiminus1, NZChiminus1, PMChiminus1]
Calcsusceps = [NMcalcsuscep, NZcalcsuscep, PMcalcsuscep]
colors = [NMcol, NZcol, PMcol]
CompoundNames = ['$\\rm{Nd_3Sb_3Mg_2O_{14}}$', '$\\rm{Nd_3Sb_3Zn_2O_{14}}$', '$\\rm{Pr_3Sb_3Mg_2O_{14}}$']
yaxeslabels = ['$\chi^{-1}$ ($\mu_B$/T/Nd)$^{-1}$', '$\chi^{-1}$ ($\mu_B$/T/Nd)$^{-1}$', 
               '$\chi^{-1}$ ($\mu_B$/T/Pr)$^{-1}$']
Fields = ['0.5 T', '0.5 T', '0.1 T']

for i,axx in enumerate(ax):
    axx.plot(Temps[i],Chiminus1s[i], 's', markersize=4,mew=0.5,mec=colors[i]*np.array([0.5,0.5,0.5,1]), 
             c=colors[i], label='data')
    axx.plot(Temps[i],-1/chifitfun(Calcsusceps[i],2), label='calculation', c=fitcolor)
    axx.plot(Temps[i],-1/Calcsusceps[i], label='calculation', c='grey')
    axx.set_ylabel(yaxeslabels[i])
    axx.text(0.5,0.96,CompoundNames[i],
            horizontalalignment='center',verticalalignment='top', transform=axx.transAxes)
    
    axx.text(0.02,0.94, '('+subplotlabels[i]+')', fontsize=16,
        horizontalalignment='left',verticalalignment='top', transform=axx.transAxes)
    axx.text(0.98,0.6, Fields[i],
        horizontalalignment='right',verticalalignment='bottom', transform=axx.transAxes)
    axx.legend(loc=4, handlelength=1.5)

ax[2].set_xlabel('$T$ (K)')
ax[2].set_xticks([0,100,200,300])
    
plt.tight_layout()
plt.subplots_adjust(hspace=0.01)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Generate LaTex Tables

# %%
#'.'.join([1,2,3])
PrMgCoefFit1.printLaTexEigenvectors()
# Out:
# \begin{table*}
# \caption{Eigenvectors and Eigenvalues...}
# \begin{ruledtabular}
# \begin{tabular}{c|ccccccccc}
# E (meV) &$|-4\rangle$ & $|-3\rangle$ & $|-2\rangle$ & $|-1\rangle$ & $|0\rangle$ & $|1\rangle$ & $|2\rangle$ & $|3\rangle$ & $|4\rangle$ \tabularnewline
#  \hline
# 0.000 & 0.3301 & 0.0176 & 0.2111 & -0.0663 & -0.8268 & 0.0663 & 0.2111 & -0.0176 & 0.3301 \tabularnewline
# 7.857 & 0.1378 & -0.0761 & 0.0021 & -0.6723 & 0.2156 & 0.6723 & 0.0021 & 0.0761 & 0.1378 \tabularnewline
# 25.982 & 0.5732 & -0.0511 & 0.294 & -0.287 & 0.0 & -0.287 & -0.294 & -0.0511 & -0.5732 \tabularnewline
# 62.734 & 0.5925 & -0.1582 & -0.1293 & 0.198 & 0.3686 & -0.198 & -0.1293 & 0.1582 & 0.5925 \tabularnewline
# 86.585 & -0.3312 & 0.2206 & 0.1273 & -0.5704 & 0.0 & -0.5704 & -0.1273 & 0.2206 & 0.3312 \tabularnewline
# 106.952 & 0.2236 & 0.1408 & -0.6201 & -0.2138 & -0.0 & -0.2138 & 0.6201 & 0.1408 & -0.2236 \tabularnewline
# ...

# %%
NdCoefFit1.printLaTexEigenvectors()
# Out:
# \begin{table*}
# \caption{Eigenvectors and Eigenvalues...}
# \begin{ruledtabular}
# \begin{tabular}{c|cccccccccc}
# E (meV) &$| -\frac{9}{2}\rangle$ & $| -\frac{7}{2}\rangle$ & $| -\frac{5}{2}\rangle$ & $| -\frac{3}{2}\rangle$ & $| -\frac{1}{2}\rangle$ & $| \frac{1}{2}\rangle$ & $| \frac{3}{2}\rangle$ & $| \frac{5}{2}\rangle$ & $| \frac{7}{2}\rangle$ & $| \frac{9}{2}\rangle$ \tabularnewline
#  \hline
# 0.000 & 0.8833 & -0.0286 & -0.0348 & 0.2094 & -0.1202 & 0.0326 & 0.3962 & 0.0355 & 0.0066 & 0.011 \tabularnewline
# 0.000 & 0.011 & -0.0066 & 0.0355 & -0.3962 & 0.0326 & 0.1202 & 0.2094 & 0.0348 & -0.0286 & -0.8833 \tabularnewline
# 23.179 & -0.4308 & 0.0814 & -0.3726 & 0.4168 & -0.0801 & 0.0886 & 0.6666 & 0.185 & -0.0385 & -0.0322 \tabularnewline
# 23.179 & 0.0322 & -0.0385 & -0.185 & 0.6666 & -0.0886 & -0.0801 & -0.4168 & -0.3726 & -0.0814 & -0.4308 \tabularnewline
# 36.360 & -0.1177 & -0.0857 & 0.4117 & 0.064 & -0.8078 & 0.3728 & -0.0209 & 0.0193 & 0.1138 & 0.0 \tabularnewline
# ...

# %%
NdZnCoefFit1.printLaTexEigenvectors()
# Out:
# \begin{table*}
# \caption{Eigenvectors and Eigenvalues...}
# \begin{ruledtabular}
# \begin{tabular}{c|cccccccccc}
# E (meV) &$| -\frac{9}{2}\rangle$ & $| -\frac{7}{2}\rangle$ & $| -\frac{5}{2}\rangle$ & $| -\frac{3}{2}\rangle$ & $| -\frac{1}{2}\rangle$ & $| \frac{1}{2}\rangle$ & $| \frac{3}{2}\rangle$ & $| \frac{5}{2}\rangle$ & $| \frac{7}{2}\rangle$ & $| \frac{9}{2}\rangle$ \tabularnewline
#  \hline
# 0.000 & 0.8077 & 0.0611 & 0.072 & 0.2893 & -0.0012 & -0.0189 & 0.4889 & -0.1198 & 0.0279 & -0.0195 \tabularnewline
# 0.000 & -0.0195 & -0.0279 & -0.1198 & -0.4889 & -0.0189 & 0.0012 & 0.2893 & -0.072 & 0.0611 & -0.8077 \tabularnewline
# 18.253 & 0.5333 & 0.1023 & -0.0497 & -0.4258 & -0.0601 & 0.1161 & -0.5039 & 0.4947 & -0.0725 & 0.0202 \tabularnewline
# 18.253 & 0.0202 & 0.0725 & 0.4947 & 0.5039 & 0.1161 & 0.0601 & -0.4258 & 0.0497 & 0.1023 & -0.5333 \tabularnewline
# ...

# %% [markdown]
# ## Plot magnetization for different directions

# %%
# Compute Magnetization
ion = 'Nd3+'

temp = 2
fieldstrengths = np.linspace(-9.1,9.1,100)
NMmagnetization = np.zeros((len(fieldstrengths), 3, 3))
NZmagnetization = np.zeros((len(fieldstrengths), 3, 3))
NMnetmag = np.zeros(len(fieldstrengths))

theta, phi = 1, 1*np.pi/6
Bvect = np.array([np.cos(phi)*np.sin(theta), np.sin(phi)*np.sin(theta), np.cos(theta)])
Bvect = np.array([1,1,1])/np.sqrt(3)

for i, fs in enumerate(fieldstrengths):
    NMmagnetization[i,0] = NdCoefFit1.magnetization(ion, temp, [fs,0,0])
    NMmagnetization[i,1] = NdCoefFit1.magnetization(ion, temp, [0,fs,0])
    NMmagnetization[i,2] = NdCoefFit1.magnetization(ion, temp, [0,0,fs])
    NMnetmag[i] = -np.dot(Bvect, np.array(NdCoefFit1.magnetization(ion, temp, fs*Bvect)))
    
    NZmagnetization[i,0] = NdZnCoefFit1.magnetization(ion, temp, [fs,0,0])
    NZmagnetization[i,1] = NdZnCoefFit1.magnetization(ion, temp, [0,fs,0])
    NZmagnetization[i,2] = NdZnCoefFit1.magnetization(ion, temp, [0,0,fs])

PMfieldstrengths = np.linspace(-155,155,100)
PMmagnetization = np.zeros((len(fieldstrengths), 3, 3))
ion='Pr3+'
for i, fs in enumerate(PMfieldstrengths):
    PMmagnetization[i,0] = PrMgCoefFit1.magnetization(ion, temp, [fs,0,0])
    PMmagnetization[i,1] = PrMgCoefFit1.magnetization(ion, temp, [0,fs,0])
    PMmagnetization[i,2] = PrMgCoefFit1.magnetization(ion, temp, [0,0,fs])
    
magnetization = [NMmagnetization, NZmagnetization, PMmagnetization]

# %%
params = {'text.usetex': False, 'mathtext.fontset': 'stixsans', 'font.size': 15}
plt.rcParams.update(params)

f, ax = plt.subplots(3,3, figsize=(7,9.3), sharey='row')
direction = ['x','y','z']
subplotlabel='abcdefghijk'
othercolors = [cpal[0],cpal[7],cpal[9]]
offdiagonal = {'ls':'--', 'lw':1.1}
diagonal = {'lw':2.4, 'zorder':10}
for i in range(3):
    for j in range(3):
        if j != 2: fs = fieldstrengths
        else: fs = PMfieldstrengths
            
        if i == 0:
            ax[j,i].plot(fs,-magnetization[j][:,i,0], label='$M_{'+direction[i]+'x}$',
                        c = colors[j], **diagonal)
            ax[j,i].plot(fs,-magnetization[j][:,i,1], label='$M_{'+direction[i]+'y}$',
                        c=othercolors[1] , **offdiagonal)
            ax[j,i].plot(fs,-magnetization[j][:,i,2], label='$M_{'+direction[i]+'z}$',
                        c=othercolors[2], **offdiagonal)
        elif i ==1:
            ax[j,i].plot(fs,-magnetization[j][:,i,0], label='$M_{'+direction[i]+'x}$',
                        c=othercolors[0] , **offdiagonal)
            ax[j,i].plot(fs,-magnetization[j][:,i,1], label='$M_{'+direction[i]+'y}$',
                        c = colors[j], **diagonal)
            ax[j,i].plot(fs,-magnetization[j][:,i,2], label='$M_{'+direction[i]+'z}$',
                        c=othercolors[2],**offdiagonal)
        elif i==2:
            ax[j,i].plot(fs,-magnetization[j][:,i,0], label='$M_{'+direction[i]+'x}$',
                        c=othercolors[0] , **offdiagonal)
            ax[j,i].plot(fs,-magnetization[j][:,i,1], label='$M_{'+direction[i]+'y}$',
                        c=othercolors[1] , **offdiagonal)
            ax[j,i].plot(fs,-magnetization[j][:,i,2], label='$M_{'+direction[i]+'z}$',
                        c = colors[j], **diagonal)
        ax[j,i].text(0.04,0.82,'B$\\parallel$'+direction[i], fontsize=13,
                    horizontalalignment='left',verticalalignment='top', transform=ax[j,i].transAxes)
        ax[j,i].legend(loc=4, frameon=False,labelspacing = 0.0, fontsize=12, handlelength=1.1)
        
        if j != 2: ax[j,i].set_xlim(-9,9)
        else: 
            ax[j,i].set_xlim(-150,150)
            ax[j,i].set_ylim(-3.6,3.6)
        if i ==0:
            if j == 2: ax[j,i].set_ylabel('$M$ ($\mu_B$/Pr)',labelpad=-5)
            else:  ax[j,i].set_ylabel('$M$ ($\mu_B$/Nd)',labelpad=-5)
        ax[j,i].set_xlabel('$B$ (T)', labelpad=0)
            
        # Label subplots
        ax[j,i].text(0.03,0.97,'('+subplotlabel[i+j*3]+')',
                    horizontalalignment='left',verticalalignment='top', transform=ax[j,i].transAxes)

ax[2,2].legend(loc=4, frameon=False,labelspacing = 0.0, fontsize=12, handlelength=0.9, ncol=2,
              columnspacing=1, bbox_to_anchor=(1,-0.04))
        
for i in range(3):
#     ax[i,1].text(0.56,0.96,CompoundNames[i], fontsize=13,
#                 horizontalalignment='center',verticalalignment='top', transform=ax[i,1].transAxes)
    ax[i,1].set_title(CompoundNames[i], fontsize=14)
    
        
#plt.tight_layout()
f.subplots_adjust(hspace=0.5, wspace=0.01)
figdir = '/home/allen/Documents/Neutrons/Nd3Sb3Mg2O14/ARCS_Exp/Paper/Figures/'
plt.savefig(figdir+'NdKag_Fig_Anisotropy.pdf',  bbox_inches='tight',pad_inches = 0.01)
# Out:
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# # Plot anisotropies all together as one figure

# %%
with open('PrMg_CEF_AnisotropyPlot.pickle', 'rb') as f:
    PMx, PMy, PMz, PMyoutline, PMzoutline,= pickle.load(f)
with open('NdMg_CEF_AnisotropyPlot.pickle', 'rb') as f:
    NMx, NMy, NMz, NMzoutline= pickle.load(f)
with open('NdZn_CEF_AnisotropyPlot.pickle', 'rb') as f:
    NZx, NZy, NZz, NZzoutline= pickle.load(f)


from mpl_toolkits.mplot3d import Axes3D

plt.rc('font',**{'size':13})
params = {'text.usetex': False, 'mathtext.fontset': 'stixsans'}
plt.rcParams.update(params)

fig3 = plt.figure(figsize=(15,4))
ax1 = fig3.add_subplot(131, projection='3d')
ax2 = fig3.add_subplot(132, projection='3d')
ax3 = fig3.add_subplot(133, projection='3d')

scale=1

x, y, z, surfaceZoutline = NMx, NMy, NMz, NMzoutline
# Plot the surface
ax1.plot_surface(x*scale, y*scale, z*scale, color='red', rstride=1, cstride=1, alpha=0.65, zorder=10)
ax1.set_yticks([-2,0,2])
ax1.set_xticks([-2,0,2])
ax1.set_zticks([-2,0,2])
surfacelineattributes = {'alpha':0.9, 'lw':2.5, 'zorder':-1}
ax1.plot(x[0],y[0]+2.5,z[0], c=pf.cpal1[1], **surfacelineattributes)
ax1.plot(x[20],y[20]+2.5,z[20], c=pf.cpal1[1], **surfacelineattributes)
ax1.plot(x[10]-2.5,y[10],z[10], c=pf.cpal1[2], **surfacelineattributes)
ax1.plot(x[30]-2.5,y[30],z[30], c=pf.cpal1[2], **surfacelineattributes)
#ax1.plot(x[:,20],y[:,20],z[:,20]-2, c=cpal1[3], **surfacelineattributes) # cross section about middle
ax1.plot(surfaceZoutline[0],surfaceZoutline[1],surfaceZoutline[2]-0.5, c=pf.cpal1[3], **surfacelineattributes)

ax1.set_xlabel('X ($\mu_B$)', labelpad=0)
ax1.set_ylabel('Y ($\mu_B$)')
ax1.set_zlabel('Z ($\mu_B$)')
ax1.set_xlim(-2.42,2.5)
ax1.set_ylim(-2.42,2.5)
ax1.set_zlim(-2.42,2.5)
ax1.tick_params(axis='z', pad=1)
ax1.tick_params(axis='x', pad=-3)
ax1.tick_params(axis='y', pad=-3)

ax1.set_title('$\\rm{Nd_3Sb_3Mg_2O_{14}}$')


x, y, z, surfaceZoutline = NZx, NZy, NZz, NZzoutline
# Plot the surface
ax2.plot_surface(x*scale, y*scale, z*scale, color=pf.cpal1[3], rstride=1, cstride=1, alpha=0.65, zorder=10)
ax2.set_yticks([-2,0,2])
ax2.set_xticks([-2,0,2])
ax2.set_zticks([-2,0,2])
surfacelineattributes = {'alpha':0.9, 'lw':2.5, 'zorder':-1}
ax2.plot(x[0],y[0]+2.5,z[0], c=pf.cpal1[1], **surfacelineattributes)
ax2.plot(x[20],y[20]+2.5,z[20], c=pf.cpal1[1], **surfacelineattributes)
ax2.plot(x[10]-2.5,y[10],z[10], c=pf.cpal1[2], **surfacelineattributes)
ax2.plot(x[30]-2.5,y[30],z[30], c=pf.cpal1[2], **surfacelineattributes)
#ax1.plot(x[:,20],y[:,20],z[:,20]-2, c=cpal1[3], **surfacelineattributes) # cross section about middle
ax2.plot(surfaceZoutline[0],surfaceZoutline[1],surfaceZoutline[2]-0.5, c=pf.cpal1[0], **surfacelineattributes)

ax2.view_init(17, -65)

ax2.set_xlabel('X ($\mu_B$)', labelpad=0)
ax2.set_ylabel('Y ($\mu_B$)')
ax2.set_zlabel('Z ($\mu_B$)')
ax2.set_xlim(-2.42,2.5)
ax2.set_ylim(-2.42,2.5)
ax2.set_zlim(-2.42,2.5)
ax2.tick_params(axis='z', pad=1)
ax2.tick_params(axis='x', pad=-3)
ax2.tick_params(axis='y', pad=-3)

ax2.set_title('$\\rm{Nd_3Sb_3Zn_2O_{14}}$')


x, y, z, surfaceZoutline, surfaceYoutline = PMx, PMy, PMz, PMzoutline, PMyoutline
# Plot the surface
ax3.plot_surface(x*scale, y*scale, z*scale, color=pf.cpal1[2], rstride=1, cstride=1, alpha=0.65, zorder=10)
surfacelineattributes = {'alpha':0.9, 'lw':2.5, 'zorder':-1}
ax3.plot(x[20]-3.55,y[20],z[20], c=pf.cpal1[0], **surfacelineattributes)
ax3.plot(x[20]-3.55,y[20],-z[20], c=pf.cpal1[0], **surfacelineattributes)
#ax1.plot(x[:,20],y[:,20],z[:,20], c=cpal1[0], **surfacelineattributes) # cross section about middle
ax3.plot(surfaceZoutline[0],surfaceZoutline[1],surfaceZoutline[2], c=pf.cpal1[3], **surfacelineattributes)
ax3.plot(-surfaceZoutline[0],surfaceZoutline[1],surfaceZoutline[2], c=pf.cpal1[3], **surfacelineattributes)
ax3.plot(surfaceYoutline[0],surfaceYoutline[1],surfaceYoutline[2], c=pf.cpal1[1], **surfacelineattributes)

# ax1.view_init(17, -65)

ax3.set_xlabel('X ($\mu_B$)', labelpad=0)
ax3.set_ylabel('Y ($\mu_B$)')
ax3.set_zlabel('Z ($\mu_B$)')
ax3.set_xlim(-3.40,3.5)
ax3.set_ylim(-3.40,3.5)
ax3.set_zlim(-3.40,3.5)
ax3.tick_params(axis='z', pad=1)
ax3.tick_params(axis='x', pad=-3)
ax3.tick_params(axis='y', pad=-3)
ax3.set_xticks([-2,0,2])
ax3.set_yticks([-2,0,2])
ax3.set_zticks([-2,0,2])

ax3.set_title('$\\rm{Pr_3Sb_3Mg_2O_{14}}$')

# Set axes labels
ax1.text(1,0,35.5, '(a)', fontsize=16,
            horizontalalignment='left',verticalalignment='top', transform=ax1.transAxes)
ax2.text(1,0,39.2, '(b)', fontsize=16,
            horizontalalignment='left',verticalalignment='top', transform=ax2.transAxes)
ax3.text(1,0,50.5, '(c)', fontsize=16,
            horizontalalignment='left',verticalalignment='top', transform=ax3.transAxes)



fig3.subplots_adjust(wspace=0.14)

figdir = '/home/allen/Documents/Neutrons/Nd3Sb3Mg2O14/ARCS_Exp/Paper/Figures/'
plt.savefig(figdir+'NdKag_Fig_Anisotropy3D.pdf',  bbox_inches='tight',pad_inches = 0.25)
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %% [markdown]
# ### Find the angle the anisotropy makes with the $z$ axis

# %%
# PMmaxM = np.hstack((np.sqrt(PMx[0]**2+PMz[0]**2),
#                    np.sqrt(PMx[20]**2+PMz[20]**2)))
PMargMax = np.argmax(np.sqrt(PMx[0]**2+PMz[0]**2))
NMargMax = np.argmax(np.sqrt(NMx[0]**2+NMz[0]**2))
NZargMax = np.argmax(np.sqrt(NZx[0]**2+NZz[0]**2))

plt.figure()
plt.plot(PMx[0],PMz[0],'g')
plt.plot(PMx[0][PMargMax], PMz[0][PMargMax], marker='o', color='g')
plt.plot(PMx[20],PMz[20],'g')
plt.plot(NZx[0],NZz[0],'purple')
plt.plot(NZx[20],NZz[20],'purple')
plt.plot(NZx[0][NZargMax], NZz[0][NZargMax], marker='o', color='purple')
plt.plot(NMx[0],NMz[0],'r')
plt.plot(NMx[20],NMz[20],'r')
plt.plot(NMx[0][NMargMax], NMz[0][NMargMax], marker='o', color='r')

print('NdMg: ', np.arctan(NMx[0][NMargMax] / NMz[0][NMargMax])*180/np.pi)

print('NdZn: ', np.arctan(NZx[0][NZargMax] / NZz[0][NZargMax])*180/np.pi)

print('PrMg: ', np.arctan(PMz[0][PMargMax] / PMx[0][PMargMax])*180/np.pi)
# Out:
# <img src="data:image/png;base64,..." width="640">
# NdMg:  0.0
# NdZn:  0.0
# PrMg:  90.0
# /home/allen/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:22: RuntimeWarning: divide by zero encountered in double_scalars

# %%
xx = 0.00 - 1.83766
yy = 4.24495 - 3.18355
zz= 0.93533 - 0.00
print(xx,yy,zz)
print(np.arctan(zz/np.sqrt(xx**2+yy**2))*180/np.pi)
# Out:
# -1.83766 1.0614000000000003 0.93533
# 23.7852119245

# %%
90-63.5
# Out:
# 26.5
